# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from CFGenerators import CFGenerators
from FeatureTweaking import feature_tweaking

def cost_func(a, b):
    return np.linalg.norm(a-b)

# %%
data = pd.read_csv('data/pima.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
feature_names = list(data.columns)[:-1]
feature_cons = {'immutable':['DiabetesPedigreeFunction'],
                'increasing':['Pregnancies', 'Age'],
                'decreasing':None,
                'data types':['int', 'int', 'int', 'int', 'int', 'float', 'float', 'int']}
dist_type = 'L1'
X = np.array(data.iloc[:,:-1])
y = np.array(data.iloc[:,-1]) 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
clf = RandomForestClassifier(n_estimators=100, max_depth=20)
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

explainer = CFGenerators(clf, X_train, feature_names, feature_cons, dist_type)
explainer.fit()

epsilon = 0.005
class_labels = [0, 1]
tc_eece = 0
tc_ft = 0
for i in range(len(y_test)):
    
    prediction = predictions[i]
    if prediction == 1:
        print(i,'=====================================================================')
        target = 1 - prediction
        x = X_test[i]
        print('Query instance:\n', x)
        
        cf, tc = feature_tweaking(clf, x, class_labels , target, epsilon, cost_func)
        print('Counterfactual generated by FT: \n', cf)

        for method in ['mo', 'discern', 'lire', 'eece']:
            cf_info = explainer.generate_cf(x, target, method, dist_type)
            print(f'Counterfactual generated by {method}: \n', cf_info['cf'])
        print('=====================================================================')
        # if i==10: break
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'] ['DiabetesPedigreeFunction'] ['Pregnancies', 'Age'] None
# Building candidate regions
# 100%|██████████████████████████████████| 100/100 [00:01<00:00, 86.93it/s]
# 7 =====================================================================
# Query instance:
#  [  0.    188.     82.     14.    185.     32.      0.682  22.   ]
# Counterfactual generated by FT:
#  [  0.         188.          82.          14.         185.
#   29.85499943   0.61749998  23.505     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  0.         107.          77.           5.           7.
#   44.90099962   0.682       24.        ]
# Counterfactual generated by eece:
#  [  0.         188.          82.          15.         185.
#   28.44999981   0.682       23.        ]
# =====================================================================
# 10 =====================================================================
# Query instance:
#  [  1.    128.     98.     41.     58.     32.      1.321  33.   ]
# Counterfactual generated by FT:
#  [  1.         128.495       98.          41.          58.
#   32.           1.11050003  33.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  1.         128.          98.          41.          58.
#   26.80000019   1.321       33.        ]
# =====================================================================
# 16 =====================================================================
# Query instance:
#  [ 10.    162.     84.      0.      0.     27.7     0.182  54.   ]
# Counterfactual generated by FT:
#  [  6.505      162.          84.           0.           0.
#   27.85499943   0.3965      54.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 10.         103.          77.          48.         166.
#   32.85100038   0.182       63.        ]
# Counterfactual generated by eece:
#  [ 10.    154.     81.      0.      0.     27.7     0.182  55.   ]
# =====================================================================
# 17 =====================================================================
# Query instance:
#  [  3.    158.     70.     30.    328.     35.5     0.344  35.   ]
# Counterfactual generated by FT:
#  [  4.495  159.495   72.995   30.     328.      32.495    0.5145  35.    ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  4.    154.     70.     30.    328.     35.5     0.344  35.   ]
# =====================================================================
# 20 =====================================================================
# Query instance:
#  [  0.    118.     84.     47.    230.     45.8     0.551  31.   ]
# Counterfactual generated by FT:
#  [  2.495  117.495   84.      47.     230.      45.8      0.6975  31.    ]
# Counterfactual generated by mo:
#  [ 3.    89.    74.    16.    85.    30.4    0.551 38.   ]
# Counterfactual generated by discern:
#  [  0.    118.     84.     16.    230.     45.8     0.551  31.   ]
# Counterfactual generated by lire:
#  [ 3.         89.         74.         16.         86.         30.65000057
#   0.551      38.        ]
# Counterfactual generated by eece:
#  [  0.    123.     81.     47.    230.     45.8     0.551  31.   ]
# =====================================================================
# 26 =====================================================================
# Query instance:
#  [  4.    146.     92.      0.      0.     31.2     0.539  61.   ]
# Counterfactual generated by FT:
#  [  4.         144.505       92.           0.           0.
#   31.2          0.46999998  61.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  8.    193.     81.      0.      0.     26.25    0.539  67.   ]
# Counterfactual generated by eece:
#  [  4.         146.          92.           0.           0.
#   29.90000057   0.539       61.        ]
# =====================================================================
# 28 =====================================================================
# Query instance:
#  [  7.    133.     84.      0.      0.     40.2     0.696  37.   ]
# Counterfactual generated by FT:
#  [  8.505      133.          84.           0.           0.
#   42.69500076   0.313       34.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 7.    97.    84.     0.     0.    40.2    0.696 37.   ]
# =====================================================================
# 29 =====================================================================
# Query instance:
#  [  4.   189.   110.    31.     0.    28.5    0.68  37.  ]
# Counterfactual generated by FT:
#  [  6.505      189.         110.          31.           0.
#   27.85499943   0.3965      37.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  7.         142.          61.          33.         188.
#   28.65100057   0.68        61.        ]
# Counterfactual generated by eece:
#  [  4.         151.         110.          31.           0.
#   27.09999943   0.68        37.        ]
# =====================================================================
# 30 =====================================================================
# Query instance:
#  [ 17.    163.     72.     41.    114.     40.9     0.817  47.   ]
# Counterfactual generated by FT:
#  [ 17.         163.          72.          41.         114.
#   42.70500076   0.313       47.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 17.     96.     72.     41.    114.     40.9     0.817  47.   ]
# =====================================================================
# 32 =====================================================================
# Query instance:
#  [  7.    181.     84.     21.    192.     35.9     0.586  51.   ]
# Counterfactual generated by FT:
#  [  2.495      181.          84.          21.         192.
#   31.19499981   0.74399999  51.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [10.    94.    73.    19.     8.    23.25   0.586 56.   ]
# Counterfactual generated by eece:
#  [  7.    125.     84.     15.    192.     35.9     0.586  51.   ]
# =====================================================================
# 36 =====================================================================
# Query instance:
#  [  5.    155.     84.     44.    545.     38.7     0.619  34.   ]
# Counterfactual generated by FT:
#  [5.00000000e+00 1.55000000e+02 8.40000000e+01 4.05050000e+01
#  5.45000000e+02 3.87000000e+01 3.42500011e-01 3.04950000e+01]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  6.         129.          90.           7.         343.
#   22.64999962   0.619       60.        ]
# Counterfactual generated by eece:
#  [  5.    127.     84.     44.    352.     38.7     0.619  34.   ]
# =====================================================================
# 37 =====================================================================
# Query instance:
#  [5.00e+00 1.68e+02 6.40e+01 0.00e+00 0.00e+00 3.29e+01 1.35e-01 4.10e+01]
# Counterfactual generated by FT:
#  [  5.         168.          61.995        0.           0.
#   29.14499962   0.6875      41.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 8.         86.         58.         20.          0.         24.59999943
#   0.135      42.        ]
# Counterfactual generated by eece:
#  [5.00e+00 1.54e+02 6.80e+01 0.00e+00 0.00e+00 3.29e+01 1.35e-01 4.10e+01]
# =====================================================================
# 39 =====================================================================
# Query instance:
#  [  9.    122.     56.      0.      0.     33.3     1.114  33.   ]
# Counterfactual generated by FT:
#  [ 10.505      122.495       56.           0.           0.
#   33.3          0.34249999  33.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 9.    95.    56.     0.     0.    33.3    1.114 33.   ]
# =====================================================================
# 44 =====================================================================
# Query instance:
#  [  3.    193.     70.     31.      0.     34.9     0.241  25.   ]
# Counterfactual generated by FT:
#  [  3.         193.          68.995       31.           0.
#   30.04500019   0.241       25.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 3.    77.    82.    28.     0.    34.5    0.241 46.   ]
# Counterfactual generated by eece:
#  [  3.    160.     70.     31.      0.     34.9     0.241  25.   ]
# =====================================================================
# 46 =====================================================================
# Query instance:
#  [  2.    129.      0.      0.      0.     38.5     0.304  41.   ]
# Counterfactual generated by FT:
#  [  2.         128.495        0.           0.           0.
#   38.5          1.11050003  41.        ]
# Counterfactual generated by mo:
#  [  7.    125.     86.      0.      0.     37.6     0.304  51.   ]
# Counterfactual generated by discern:
#  [  7.    129.     86.      0.      0.     38.5     0.304  51.   ]
# Counterfactual generated by lire:
#  [  7.         125.          86.           0.           0.
#   37.79999924   0.304       51.        ]
# Counterfactual generated by eece:
#  [  2.    122.      0.      0.      0.     38.5     0.304  41.   ]
# =====================================================================
# 50 =====================================================================
# Query instance:
#  [  4.    115.     72.      0.      0.     28.9     0.376  46.   ]
# Counterfactual generated by FT:
#  [  4.         114.495       72.           0.           0.
#   26.44499981   0.376       46.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [12.         89.         74.         40.         39.         35.10100038
#   0.376      48.        ]
# Counterfactual generated by eece:
#  [  4.         115.          72.           0.           0.
#   28.84999943   0.376       46.        ]
# =====================================================================
# 51 =====================================================================
# Query instance:
#  [8.00e+00 1.43e+02 6.60e+01 0.00e+00 0.00e+00 3.49e+01 1.29e-01 4.10e+01]
# Counterfactual generated by FT:
#  [8.00000000e+00 1.43000000e+02 6.89950000e+01 0.00000000e+00
#  0.00000000e+00 3.00450002e+01 1.29000000e-01 4.10000000e+01]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  8.    127.     68.      0.      0.     34.9     0.129  41.   ]
# =====================================================================
# 55 =====================================================================
# Query instance:
#  [  4.    171.     72.      0.      0.     43.6     0.479  26.   ]
# Counterfactual generated by FT:
#  [  4.         171.          72.           0.           0.
#   43.6          0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  4.         116.          72.           9.          84.
#   22.64999962   0.479       37.        ]
# Counterfactual generated by eece:
#  [  4.    127.     72.      0.      0.     43.6     0.479  26.   ]
# =====================================================================
# 64 =====================================================================
# Query instance:
#  [  1.    172.     68.     49.    579.     42.4     0.702  28.   ]
# Counterfactual generated by FT:
#  [1.00000000e+00 1.72000000e+02 6.80000000e+01 4.90000000e+01
#  5.79000000e+02 4.27050008e+01 3.13000004e-01 2.80000000e+01]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  4.         120.          68.           5.           7.
#   29.60000038   0.702       34.        ]
# Counterfactual generated by eece:
#  [  1.    139.     68.     49.    479.     42.4     0.702  28.   ]
# =====================================================================
# 69 =====================================================================
# Query instance:
#  [6.00e+00 1.34e+02 8.00e+01 3.70e+01 3.70e+02 4.62e+01 2.38e-01 4.60e+01]
# Counterfactual generated by FT:
#  [  6.         136.505       80.          37.         370.
#   46.2          1.42250001  46.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [6.00e+00 1.27e+02 8.00e+01 3.70e+01 3.70e+02 4.62e+01 2.38e-01 4.60e+01]
# =====================================================================
# 70 =====================================================================
# Query instance:
#  [  6.    154.     78.     41.    140.     46.1     0.571  27.   ]
# Counterfactual generated by FT:
#  [  7.495 154.     78.     43.505 143.005  46.1     0.84   27.   ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 8.         78.         73.         23.          8.         32.14999962
#   0.571      42.        ]
# Counterfactual generated by eece:
#  [  6.    154.     78.     41.    163.     46.1     0.571  27.   ]
# =====================================================================
# 71 =====================================================================
# Query instance:
#  [  0.    180.     90.     26.     90.     36.5     0.314  35.   ]
# Counterfactual generated by FT:
#  [  2.495      180.          90.          26.          90.
#   31.19499981   0.74399999  35.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 6.    91.    67.    29.     7.    26.25   0.314 41.   ]
# Counterfactual generated by eece:
#  [  0.    151.     90.     26.     90.     36.5     0.314  35.   ]
# =====================================================================
# 73 =====================================================================
# Query instance:
#  [  3.    170.     64.     37.    225.     34.5     0.356  30.   ]
# Counterfactual generated by FT:
#  [  3.         170.          64.          37.         225.
#   34.5          0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [12.         89.         74.         40.         57.         35.10100038
#   0.356      48.        ]
# Counterfactual generated by eece:
#  [  3.    151.     64.     37.    225.     34.5     0.356  30.   ]
# =====================================================================
# 75 =====================================================================
# Query instance:
#  [  9.    102.     76.     37.      0.     32.9     0.665  46.   ]
# Counterfactual generated by FT:
#  [  9.         102.          76.          36.495        0.
#   28.84499943   0.665       46.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 9.    96.    76.    37.     0.    32.9    0.665 46.   ]
# =====================================================================
# 79 =====================================================================
# Query instance:
#  [  5.    189.     64.     33.    325.     31.2     0.583  29.   ]
# Counterfactual generated by FT:
#  [  5.         189.          64.          33.         325.
#   31.2          0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  6.         129.          90.           7.         325.
#   22.64999962   0.583       60.        ]
# Counterfactual generated by eece:
#  [  5.         154.          64.          33.         325.
#   31.45099981   0.583       29.        ]
# =====================================================================
# 90 =====================================================================
# Query instance:
#  [7.00e+00 1.87e+02 6.80e+01 3.90e+01 3.04e+02 3.77e+01 2.54e-01 4.10e+01]
# Counterfactual generated by FT:
#  [  7.         187.          68.          39.         304.
#   42.70500076   0.313       41.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [7.00e+00 1.54e+02 6.50e+01 3.90e+01 3.04e+02 3.77e+01 2.54e-01 4.10e+01]
# =====================================================================
# 96 =====================================================================
# Query instance:
#  [ 13.    158.    114.      0.      0.     42.3     0.257  44.   ]
# Counterfactual generated by FT:
#  [  8.505      158.         114.           0.           0.
#   42.69500076   0.313       34.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 13.    127.    114.      0.      0.     42.3     0.257  44.   ]
# =====================================================================
# 101 =====================================================================
# Query instance:
#  [9.00e+00 1.24e+02 7.00e+01 3.30e+01 4.02e+02 3.54e+01 2.82e-01 3.40e+01]
# Counterfactual generated by FT:
#  [1.04950e+01 1.22495e+02 7.00000e+01 3.30000e+01 4.02000e+02 3.54000e+01
#  2.82000e-01 3.40000e+01]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [9.00e+00 9.90e+01 7.00e+01 3.30e+01 4.02e+02 3.54e+01 2.82e-01 3.40e+01]
# =====================================================================
# 105 =====================================================================
# Query instance:
#  [  2.    128.     64.     42.      0.     40.      1.101  24.   ]
# Counterfactual generated by FT:
#  [  1.495  127.505   64.      41.495    0.      40.       0.3165  23.495 ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  2.    127.     64.     42.      0.     40.      1.101  24.   ]
# =====================================================================
# 106 =====================================================================
# Query instance:
#  [  8.    120.      0.      0.      0.     30.      0.183  38.   ]
# Counterfactual generated by FT:
#  [  8.         120.495        0.           0.           0.
#   29.54500019   0.36200001  38.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [13.         78.         60.          0.          0.         32.60100038
#   0.183      41.        ]
# Counterfactual generated by eece:
#  [  8.         120.           0.           0.           0.
#   29.85000038   0.183       38.        ]
# =====================================================================
# 108 =====================================================================
# Query instance:
#  [  4.    183.      0.      0.      0.     28.4     0.212  36.   ]
# Counterfactual generated by FT:
#  [  6.505      183.           0.           0.           0.
#   27.85499943   0.3965      36.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  5.         158.          70.           0.           0.
#   29.65100057   0.212       63.        ]
# Counterfactual generated by eece:
#  [  4.         153.           0.           0.           0.
#   26.89999962   0.212       36.        ]
# =====================================================================
# 118 =====================================================================
# Query instance:
#  [  9.    123.     70.     44.     94.     33.1     0.374  40.   ]
# Counterfactual generated by FT:
#  [ 10.495 122.495  70.     44.     94.     33.1     0.374  40.   ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [12.         89.         74.         40.         57.         35.10100038
#   0.374      48.        ]
# Counterfactual generated by eece:
#  [  9.    122.     70.     44.     94.     33.1     0.374  40.   ]
# =====================================================================
# 120 =====================================================================
# Query instance:
#  [2.00e+00 1.57e+02 7.40e+01 3.50e+01 4.40e+02 3.94e+01 1.34e-01 3.00e+01]
# Counterfactual generated by FT:
#  [  2.         157.          74.          35.         440.
#   39.4          0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 8.         86.         58.         20.          8.         24.59999943
#   0.134      42.        ]
# Counterfactual generated by eece:
#  [2.00e+00 1.54e+02 7.40e+01 3.50e+01 4.40e+02 3.94e+01 1.34e-01 3.00e+01]
# =====================================================================
# 122 =====================================================================
# Query instance:
#  [0.00e+00 1.65e+02 9.00e+01 3.30e+01 6.80e+02 5.23e+01 4.27e-01 2.30e+01]
# Counterfactual generated by FT:
#  [4.49500000e+00 1.66495000e+02 9.00000000e+01 3.30000000e+01
#  6.80000000e+02 4.80950004e+01 5.27999992e-01 2.30000000e+01]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 1.         89.         63.         24.         46.         29.94999981
#   0.427      23.        ]
# Counterfactual generated by eece:
#  [0.00e+00 1.39e+02 9.00e+01 3.30e+01 4.79e+02 5.23e+01 4.27e-01 2.30e+01]
# =====================================================================
# 124 =====================================================================
# Query instance:
#  [5.00e+00 1.62e+02 1.04e+02 0.00e+00 0.00e+00 3.77e+01 1.51e-01 5.20e+01]
# Counterfactual generated by FT:
#  [  4.495      166.495      104.           0.           0.
#   37.7          0.52799999  52.        ]
# Counterfactual generated by mo:
#  [  6.    137.     61.      0.      0.     24.2     0.151  55.   ]
# Counterfactual generated by discern:
#  [  6.    137.     61.      0.      0.     24.2     0.151  55.   ]
# Counterfactual generated by lire:
#  [  6.    138.     61.      0.      0.     24.25    0.151  55.   ]
# Counterfactual generated by eece:
#  [  5.    143.    104.      0.      0.     37.7     0.151  52.   ]
# =====================================================================
# 126 =====================================================================
# Query instance:
#  [ 12.    140.     82.     43.    325.     39.2     0.528  58.   ]
# Counterfactual generated by FT:
#  [1.20000000e+01 1.40000000e+02 8.20000000e+01 4.30000000e+01
#  3.25000000e+02 4.27050008e+01 3.13000004e-01 5.80000000e+01]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 12.     91.     73.     43.    325.     39.2     0.528  58.   ]
# =====================================================================
# 127 =====================================================================
# Query instance:
#  [  0.    162.     76.     36.      0.     49.6     0.364  26.   ]
# Counterfactual generated by FT:
#  [  2.495 159.995  76.     36.      0.     49.6     0.364  28.495]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 5.         95.         72.         33.          0.         37.95000076
#   0.364      27.        ]
# Counterfactual generated by eece:
#  [  0.    124.     76.     36.      0.     49.6     0.364  26.   ]
# =====================================================================
# 129 =====================================================================
# Query instance:
#  [  7.    133.     88.     15.    155.     32.4     0.262  37.   ]
# Counterfactual generated by FT:
#  [  2.495      133.          88.          15.         155.
#   31.19499981   0.74399999  37.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  7.    135.     88.     15.    155.     32.4     0.262  37.   ]
# =====================================================================
# 133 =====================================================================
# Query instance:
#  [  9.   106.    52.     0.     0.    31.2    0.38  42.  ]
# Counterfactual generated by FT:
#  [  6.505      107.505       52.           0.           0.
#   31.2          0.24450001  42.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [12.         89.         74.         40.         39.         35.10100038
#   0.38       48.        ]
# Counterfactual generated by eece:
#  [  9.   103.    52.     0.     0.    31.2    0.38  42.  ]
# =====================================================================
# 134 =====================================================================
# Query instance:
#  [  2.  106.   64.   35.  119.   30.5   1.4  34. ]
# Counterfactual generated by FT:
#  [  2.         106.          64.          35.         120.995
#   29.59500038   1.01949998  34.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  2.   99.   64.   35.  119.   30.5   1.4  34. ]
# =====================================================================
# 135 =====================================================================
# Query instance:
#  [  5.    158.     84.     41.    210.     39.4     0.395  29.   ]
# Counterfactual generated by FT:
#  [  5.         158.          84.          41.         210.
#   39.4          0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  5.    154.     84.     41.    210.     39.4     0.395  29.   ]
# =====================================================================
# 136 =====================================================================
# Query instance:
#  [  7.    150.     78.     29.    126.     35.2     0.692  54.   ]
# Counterfactual generated by FT:
#  [  7.         151.495       76.495       29.         120.995
#   35.2          0.85500002  54.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  7.         150.          78.          29.         121.
#   27.30000019   0.692       54.        ]
# =====================================================================
# 141 =====================================================================
# Query instance:
#  [  9.    170.     74.     31.      0.     44.      0.403  43.   ]
# Counterfactual generated by FT:
#  [  4.495      166.495       74.          31.           0.
#   44.           0.52799999  43.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  9.    122.     74.     31.     37.     44.      0.403  43.   ]
# =====================================================================
# 142 =====================================================================
# Query instance:
#  [  2.    128.     78.     37.    182.     43.3     1.224  31.   ]
# Counterfactual generated by FT:
#  [  2.         128.495       78.          37.         182.
#   43.3          1.11050003  31.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  2.    121.     78.     48.    182.     43.3     1.224  31.   ]
# =====================================================================
# 143 =====================================================================
# Query instance:
#  [7.00e+00 1.42e+02 9.00e+01 2.40e+01 4.80e+02 3.04e+01 1.28e-01 4.30e+01]
# Counterfactual generated by FT:
#  [6.50500000e+00 1.42000000e+02 9.00000000e+01 2.40000000e+01
#  4.80000000e+02 2.78549994e+01 3.96500002e-01 4.30000000e+01]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [7.00000000e+00 1.42000000e+02 9.00000000e+01 2.40000000e+01
#  4.80000000e+02 2.78499994e+01 1.28000000e-01 4.30000000e+01]
# =====================================================================
# 160 =====================================================================
# Query instance:
#  [ 12.    140.     85.     33.      0.     37.4     0.244  41.   ]
# Counterfactual generated by FT:
#  [ 12.         140.          85.          32.495        0.
#   29.54500019   0.209       38.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 12.    140.     88.     36.      0.     37.4     0.244  41.   ]
# =====================================================================
# 162 =====================================================================
# Query instance:
#  [  0.    180.     66.     39.      0.     42.      1.893  25.   ]
# Counterfactual generated by FT:
#  [  0.         180.          66.          39.           0.
#   42.           0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  0.         146.          82.           3.           0.
#   40.79999924   1.893       44.        ]
# Counterfactual generated by eece:
#  [  0.    127.     66.     39.      0.     42.      1.893  25.   ]
# =====================================================================
# 168 =====================================================================
# Query instance:
#  [ 13.    126.     90.      0.      0.     43.4     0.583  42.   ]
# Counterfactual generated by FT:
#  [ 10.505      122.495       90.           0.           0.
#   43.4          0.34249999  42.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 13.    122.     90.      0.      0.     43.4     0.583  42.   ]
# =====================================================================
# 169 =====================================================================
# Query instance:
#  [  8.    179.     72.     42.    130.     32.7     0.719  36.   ]
# Counterfactual generated by FT:
#  [  8.         179.          68.995       42.         130.
#   30.04500019   0.719       36.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  8.         149.          72.          42.         130.
#   26.44999981   0.719       36.        ]
# =====================================================================
# 178 =====================================================================
# Query instance:
#  [ 10.   129.    76.    28.   122.    35.9    0.28  39.  ]
# Counterfactual generated by FT:
#  [ 10.         128.495       76.          28.         122.
#   35.9          1.11050003  39.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 10.   122.    76.    28.   112.    35.9    0.28  39.  ]
# =====================================================================
# 180 =====================================================================
# Query instance:
#  [  7.    109.     80.     31.      0.     35.9     1.127  43.   ]
# Counterfactual generated by FT:
#  [  6.505      103.495       80.995       31.           0.
#   35.9          0.51950001  43.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 7.    81.    79.    31.     0.    35.9    1.127 43.   ]
# =====================================================================
# 184 =====================================================================
# Query instance:
#  [  9.    119.     80.     35.      0.     29.      0.263  29.   ]
# Counterfactual generated by FT:
#  [  9.         119.          80.          35.           0.
#   29.           0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [  9.    119.     79.     35.      0.     29.      0.263  29.   ]
# =====================================================================
# 185 =====================================================================
# Query instance:
#  [  1.    146.     56.      0.      0.     29.7     0.564  29.   ]
# Counterfactual generated by FT:
#  [  1.         146.          56.           0.           0.
#   29.7          0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [ 5.         82.         62.          0.          0.         25.30000019
#   0.564      35.        ]
# Counterfactual generated by eece:
#  [  1.         144.          56.           0.           0.
#   28.65000057   0.564       29.        ]
# =====================================================================
# 186 =====================================================================
# Query instance:
#  [  1.    122.     90.     51.    220.     49.7     0.325  31.   ]
# Counterfactual generated by FT:
#  [  1.         122.          90.          51.         220.
#   49.7          0.83700001  28.495     ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Counterfactual generated by lire:
#  [  6.         103.          73.          32.         192.
#   37.95000076   0.325       55.        ]
# Counterfactual generated by eece:
#  [  1.    122.     90.     51.    226.     49.7     0.325  31.   ]
# =====================================================================
# 189 =====================================================================
# Query instance:
#  [ 10.    161.     68.     23.    132.     25.5     0.326  47.   ]
# Counterfactual generated by FT:
#  [  6.495      161.495       68.          23.         132.
#   26.94499981   0.208       47.        ]
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by mo:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by discern:
#  None
# Your feature constrains are too strict for this instance! Can't generate satisfied counterfactual example!
# Counterfactual generated by lire:
#  None
# Counterfactual generated by eece:
#  [ 10.    154.     68.     23.    126.     25.5     0.326  47.   ]
# =====================================================================
